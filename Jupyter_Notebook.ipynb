# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# ### (Title): Tools of Data Science

# %% [markdown]
# ##### (Introduction) Hello! We'll be going over some Tools of Data Science

# %% [markdown]
# ###### (Data Science Languages) R, Python, SQL, Julia, Scala, Java, C++

# %% [markdown]
# ###### (Data Science Libraries) Weka, Java-ML, Apache MLib, Deeplearning4, Shark, GraphX, Spark Streaming, TensorFlow, Caffe

# %% [markdown]
# ###### (Data Science Tools) H20.ai, Amazon DynamoDB, Cloudant, IBM DB2, Informatica, IBM Data Refinery, Datameer, IBM Cognos Analytics, IBM Watson Studio, IBM Watson Machine Learning, Google CLoud

# %% [markdown]
# #### Examples Of Arithmetic Expressions:

# %%
#This a simple arithmetic expression to add then multiply integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours
def minutestoHours(minutes):
    hour =  minutes/60 
    return hour;

time = minutestoHours(200)
print(time)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
#
# Your grade will be based on the following Exercises:
#
# * Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# * Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# * Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# * Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# * Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# * Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# * Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
#
# * Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
#
# * Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# * Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# * Exercise 12 - Share your notebook through GitHub (3 pts)
#
# * Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ##### Author Name: Justin Andrew

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
